# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0517-beep/Nasscom/blob/main/List%2C_tuple_set_and_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['apple', 'banana', 'cherry', 'apple',]
print("original list:", fruits)
print("First fruit:", fruits[0])
# Out:
# original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
#adding an item
fruits.append('orange')
print("After appending:", fruits)
#removing an item
fruits.remove('banana')
print("After removing banana:", fruits)
#List length
print("Number of fruits:", len(fruits))
# Out:
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']
# After removing banana: ['apple', 'cherry', 'apple', 'orange']
# Number of fruits: 4

# %%
dimensions = (10,20,30)
print("Tuple:", dimensions)
print("second element:", dimensions[1])
unique_numbers = {1,2,3,2,1}
print("set( no duplicates):", unique_numbers)
# Out:
# Tuple: (10, 20, 30)
# second element: 20
# set( no duplicates): {1, 2, 3}

# %%
#adding elements
unique_numbers.add(4)
print("after adding 4:", unique_numbers)
#removing elements
unique_numbers.remove(2)
print("after removing 2:", unique_numbers)
# Out:
# after adding 4: {1, 2, 3, 4}
# after removing 2: {1, 3, 4}

# %%
#set operations
set_a = {1,2,3}
set_b = {3,4,5}
print("union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A-B):", set_a - set_b)
# Out:
# union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A-B): {1, 2}

# %%
students = {
    'name': 'Alice',
    'age': 21,
    'coding': 'python'
}
print("Dictionary:", students)
# Out:
# Dictionary: {'name': 'Alice', 'age': 21, 'coding': 'python'}

# %%
keys = ['id', 'name', 'marks']
values = [101,'John', 88]
student_info = dict(zip(keys, values))
print("student Info from zip:", student_info)
# Out:
# student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
