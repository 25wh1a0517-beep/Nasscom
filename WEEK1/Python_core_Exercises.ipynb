# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0517-beep/Nasscom/blob/main/Python_core_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
# Task 1.1: Generate 100 simulated sensor readings

raw_sensor_data = []

for i in range(1, 101):
    # Generate timestamp
    timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    # Generate unique device ID
    device_id = f'DEV{i:03d}'

    # Random device type
    device_type = random.choice(DEVICE_TYPES)

    # Random location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Store reading as a tuple
    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

print("Number of readings:", len(raw_sensor_data))
print("\nFirst 5 readings:")
for reading in raw_sensor_data[:5]:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Number of readings: 100
#
# First 5 readings:
# ('2026-08-17 05:40:11', 'DEV001', 'Light_Sensor', 'OfficeB', 834.67)
# ('2026-08-17 05:40:11', 'DEV002', 'Temperature_Sensor', 'OfficeA', 29.55)
# ('2026-08-17 05:40:11', 'DEV003', 'Temperature_Sensor', 'Lab1', 21.1)
# ('2026-08-17 05:40:11', 'DEV004', 'Humidity_Sensor', 'OfficeA', 47.32)
# ('2026-08-17 05:40:11', 'DEV005', 'Humidity_Sensor', 'OfficeA', 41.81)

# %%
# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
# Task 1.2: Create temperature_readings list

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print("Temperature readings:")
print(temperature_readings)
# Out:
# Temperature readings:
# [{'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV002', 'location': 'OfficeA', 'temperature_celsius': 29.55}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV003', 'location': 'Lab1', 'temperature_celsius': 21.1}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV006', 'location': 'OfficeA', 'temperature_celsius': 20.16}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV008', 'location': 'Warehouse', 'temperature_celsius': 24.19}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV011', 'location': 'Lab2', 'temperature_celsius': 22.22}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV018', 'location': 'Warehouse', 'temperature_celsius': 18.46}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV022', 'location': 'OfficeB', 'temperature_celsius': 28.3}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV023', 'location': 'Lab1', 'temperature_celsius': 19.93}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV028', 'location': 'Lab2', 'temperature_celsius': 23.06}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV030', 'location': 'Warehouse', 'temperature_celsius': 20.19}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV034', 'location': 'Warehouse', 'temperature_celsius': 24.39}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV036', 'location': 'OfficeB', 'temperature_celsius': 25.97}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV038', 'location': 'Lab1', 'temperature_celsius': 24.32}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV040', 'location': 'OfficeA', 'temperature_celsius': 29.2}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV044', 'location': 'Warehouse', 'temperature_celsius': 18.64}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV045', 'location': 'OfficeB', 'temperature_celsius': 27.31}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV051', 'location': 'Lab1', 'temperature_celsius': 27.65}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV053', 'location': 'OfficeB', 'temperature_celsius': 22.15}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV069', 'location': 'Lab1', 'temperature_celsius': 22.62}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV079', 'location': 'OfficeA', 'temperature_celsius': 22.97}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV080', 'location': 'OfficeA', 'temperature_celsius': 18.57}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV085', 'location': 'OfficeB', 'temperature_celsius': 28.39}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV086', 'location': 'OfficeB', 'temperature_celsius': 18.75}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV089', 'location': 'Lab2', 'temperature_celsius': 28.46}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV095', 'location': 'Warehouse', 'temperature_celsius': 27.47}, {'timestamp': '2026-08-17 05:40:11', 'device_id': 'DEV096', 'location': 'OfficeB', 'temperature_celsius': 19.65}]

# %%
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
# Task 1.3: Create a set of unique locations

unique_locations = set()

for reading in raw_sensor_data:
    location = reading[3]
    unique_locations.add(location)

print("Unique locations:")
print(unique_locations)
# Out:
# Unique locations:
# {'Lab1', 'OfficeB', 'OfficeA', 'Lab2', 'Warehouse'}

# %%
# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
# Task 1.4: Create device_stats dictionary

device_stats = {}

# Initialize with large/small values
for device_type in DEVICE_TYPES:
    device_stats[device_type] = (float('inf'), float('-inf'))

# Find minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    device_stats[device_type] = (
        min(min_value, value),
        max(max_value, value)
    )

print("Device Statistics:")
print(device_stats)
# Out:
# Device Statistics:
# {'Temperature_Sensor': (18.46, 29.55), 'Humidity_Sensor': (32.01, 79.52), 'Pressure_Sensor': (980.38, 1028.35), 'Light_Sensor': (116.23, 982.43)}

# %%
# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
# Task 1.5.1: Advanced List Slicing

# Extract elements from the 10th to the 20th (inclusive)
# Python index starts from 0, so use index 9 to 20
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

print("Readings from 10th to 20th:")
print(sliced_readings_1)

print("\nEvery 5th reading:")
print(sliced_readings_2)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Readings from 10th to 20th:
# [('2026-08-17 05:40:11', 'DEV010', 'Humidity_Sensor', 'OfficeB', 46.11), ('2026-08-17 05:40:11', 'DEV011', 'Temperature_Sensor', 'Lab2', 22.22), ('2026-08-17 05:40:11', 'DEV012', 'Light_Sensor', 'OfficeA', 144.5), ('2026-08-17 05:40:11', 'DEV013', 'Light_Sensor', 'OfficeA', 220.38), ('2026-08-17 05:40:11', 'DEV014', 'Light_Sensor', 'OfficeA', 893.72), ('2026-08-17 05:40:11', 'DEV015', 'Light_Sensor', 'Warehouse', 844.97), ('2026-08-17 05:40:11', 'DEV016', 'Pressure_Sensor', 'Lab1', 1027.64), ('2026-08-17 05:40:11', 'DEV017', 'Light_Sensor', 'OfficeA', 866.24), ('2026-08-17 05:40:11', 'DEV018', 'Temperature_Sensor', 'Warehouse', 18.46), ('2026-08-17 05:40:11', 'DEV019', 'Light_Sensor', 'OfficeB', 877.1), ('2026-08-17 05:40:11', 'DEV020', 'Pressure_Sensor', 'Lab2', 991.61)]
#
# Every 5th reading:
# [('2026-08-17 05:40:11', 'DEV001', 'Light_Sensor', 'OfficeB', 834.67), ('2026-08-17 05:40:11', 'DEV006', 'Temperature_Sensor', 'OfficeA', 20.16), ('2026-08-17 05:40:11', 'DEV011', 'Temperature_Sensor', 'Lab2', 22.22), ('2026-08-17 05:40:11', 'DEV016', 'Pressure_Sensor', 'Lab1', 1027.64), ('2026-08-17 05:40:11', 'DEV021', 'Pressure_Sensor', 'Lab1', 1019.6), ('2026-08-17 05:40:11', 'DEV026', 'Humidity_Sensor', 'Warehouse', 70.17), ('2026-08-17 05:40:11', 'DEV031', 'Light_Sensor', 'Lab1', 512.0), ('2026-08-17 05:40:11', 'DEV036', 'Temperature_Sensor', 'OfficeB', 25.97), ('2026-08-17 05:40:11', 'DEV041', 'Humidity_Sensor', 'Lab1', 77.99), ('2026-08-17 05:40:11', 'DEV046', 'Pressure_Sensor', 'Warehouse', 1016.93), ('2026-08-17 05:40:11', 'DEV051', 'Temperature_Sensor', 'Lab1', 27.65), ('2026-08-17 05:40:11', 'DEV056', 'Light_Sensor', 'Lab2', 190.18), ('2026-08-17 05:40:11', 'DEV061', 'Light_Sensor', 'OfficeA', 136.26), ('2026-08-17 05:40:11', 'DEV066', 'Light_Sensor', 'Warehouse', 845.84), ('2026-08-17 05:40:11', 'DEV071', 'Light_Sensor', 'Lab2', 833.11), ('2026-08-17 05:40:11', 'DEV076', 'Humidity_Sensor', 'OfficeB', 49.34), ('2026-08-17 05:40:11', 'DEV081', 'Pressure_Sensor', 'Lab1', 1026.87), ('2026-08-17 05:40:11', 'DEV086', 'Temperature_Sensor', 'OfficeB', 18.75), ('2026-08-17 05:40:11', 'DEV091', 'Light_Sensor', 'OfficeB', 676.93), ('2026-08-17 05:40:11', 'DEV096', 'Temperature_Sensor', 'OfficeB', 19.65)]

# %%
# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
# Task 1.5.2: String Slicing

# Extract "Programming"
substring_1 = sample_string[6:17]

# Extract "nohtyP" by reversing "Python"
substring_2 = sample_string[5::-1]

print("substring_1:", substring_1)
print("substring_2:", substring_2)
# Out:
# substring_1: Programming
# substring_2: nohtyP

# %%
# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
# Task 1.5.3: Mixed Slicing

# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print("5th reading device type:", fifth_reading_device_type)
print("Device type suffix:", device_type_suffix)
# Out:
# 5th reading device type: Humidity_Sensor
# Device type suffix: Sensor

# %%
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:

# Task 2.1: Function to get readings by location

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        location = reading[3]

        if location == target_location:
            result.append(reading)

    return result


# Example usage
location_readings = get_readings_by_location(raw_sensor_data, 'Lab1')

print("Readings from Lab1:")
print(location_readings)
# Out:
# --- Task 2: Function Definitions and Usage ---
# Readings from Lab1:
# [('2026-08-17 05:40:11', 'DEV003', 'Temperature_Sensor', 'Lab1', 21.1), ('2026-08-17 05:40:11', 'DEV009', 'Light_Sensor', 'Lab1', 982.43), ('2026-08-17 05:40:11', 'DEV016', 'Pressure_Sensor', 'Lab1', 1027.64), ('2026-08-17 05:40:11', 'DEV021', 'Pressure_Sensor', 'Lab1', 1019.6), ('2026-08-17 05:40:11', 'DEV023', 'Temperature_Sensor', 'Lab1', 19.93), ('2026-08-17 05:40:11', 'DEV031', 'Light_Sensor', 'Lab1', 512.0), ('2026-08-17 05:40:11', 'DEV033', 'Pressure_Sensor', 'Lab1', 986.6), ('2026-08-17 05:40:11', 'DEV038', 'Temperature_Sensor', 'Lab1', 24.32), ('2026-08-17 05:40:11', 'DEV039', 'Humidity_Sensor', 'Lab1', 58.19), ('2026-08-17 05:40:11', 'DEV041', 'Humidity_Sensor', 'Lab1', 77.99), ('2026-08-17 05:40:11', 'DEV050', 'Light_Sensor', 'Lab1', 513.99), ('2026-08-17 05:40:11', 'DEV051', 'Temperature_Sensor', 'Lab1', 27.65), ('2026-08-17 05:40:11', 'DEV060', 'Pressure_Sensor', 'Lab1', 983.15), ('2026-08-17 05:40:11', 'DEV064', 'Light_Sensor', 'Lab1', 162.31), ('2026-08-17 05:40:11', 'DEV067', 'Light_Sensor', 'Lab1', 608.63), ('2026-08-17 05:40:11', 'DEV068', 'Pressure_Sensor', 'Lab1', 1023.55), ('2026-08-17 05:40:11', 'DEV069', 'Temperature_Sensor', 'Lab1', 22.62), ('2026-08-17 05:40:11', 'DEV072', 'Pressure_Sensor', 'Lab1', 1012.05), ('2026-08-17 05:40:11', 'DEV074', 'Humidity_Sensor', 'Lab1', 73.78), ('2026-08-17 05:40:11', 'DEV077', 'Pressure_Sensor', 'Lab1', 988.63), ('2026-08-17 05:40:11', 'DEV081', 'Pressure_Sensor', 'Lab1', 1026.87), ('2026-08-17 05:40:11', 'DEV087', 'Humidity_Sensor', 'Lab1', 48.36), ('2026-08-17 05:40:11', 'DEV094', 'Humidity_Sensor', 'Lab1', 32.01), ('2026-08-17 05:40:11', 'DEV098', 'Pressure_Sensor', 'Lab1', 980.38), ('2026-08-17 05:40:11', 'DEV099', 'Light_Sensor', 'Lab1', 682.06)]

# %%
# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
# Task 2.2: Calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading['temperature_celsius']

    average = total / len(temp_data_list)

    return average


# Example usage
average_temperature = calculate_average_temperature(temperature_readings)

print("Average Temperature:", average_temperature)
# Out:
# Average Temperature: 23.602692307692305

# %%
# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
# Task 2.3: Generate a formatted report line

def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


# Example usage
if temperature_readings:
    report_line = generate_report_line(temperature_readings[0])
    print(report_line)
# Out:
# [2026-08-17 05:40:11] Device DEV002 at OfficeA: 29.55°C

# %%
# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
# Task 3.3: Generate 5 random integer values between 100 and 200

random_values = []

for i in range(5):
    value = random.randint(100, 200)
    random_values.append(value)

print("Random values:", random_values)
# Out:
# Random values: [174, 130, 155, 192, 170]

# %%
# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")
# Out:
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %%
# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
# Task 4.2: Read the report file

with open('sensor_reports/temperature_report.txt', 'r') as file:
    read_report_lines = file.readlines()

print("First 3 lines:")
for line in read_report_lines[:3]:
    print(line.strip())
# Out:
# First 3 lines:
# [2026-08-17 05:40:11] Device DEV002 at OfficeA: 29.55°C
# [2026-08-17 05:40:11] Device DEV003 at Lab1: 21.1°C
# [2026-08-17 05:40:11] Device DEV006 at OfficeA: 20.16°C

# %%
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
