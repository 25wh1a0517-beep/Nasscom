# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0517-beep/Nasscom/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/dataset - Sheet1 (1).csv")
df.head()
# Out:
#    s.no  Rollno     name  age
# 0     1     501  shruthi   18
# 1     2     502    suppu   17
# 2     3     503   pretty   17
# 3     4     504    glory   19
# 4     5     505   harika   18
