# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0517-beep/Nasscom/blob/main/pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.

# Your code for Task 1 here:
# 1.1 Create a Pandas Series
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array with random integers between 1 and 100
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert NumPy array into a Pandas DataFrame
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

print("Series:")
print(s1_1)

print("\nNumPy Array:")
print(np_array1_2)

print("\nDataFrame:")
print(df1_3)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# NumPy Array:
# [[ 77  54  81   2]
#  [  7  62  23  27]
#  [ 55 100  13  87]]
#
# DataFrame:
#     A    B   C   D
# 0  77   54  81   2
# 1   7   62  23  27
# 2  55  100  13  87

# %%
# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

# Your code for Task 2 here:
# Task 2: Synthetic Data Generation for Practice

# Generate 100 dates
dates = pd.date_range(start='2023-01-01', end='2023-04-09', periods=100)

# Create DataFrame
df_sales = pd.DataFrame({
    'Date': dates,
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100),
    'Quantity': np.random.randint(1, 11, 100)
})

# Introduce 5 random NaN values in Sales
sales_nan_indices = np.random.choice(df_sales.index, 5, replace=False)
df_sales.loc[sales_nan_indices, 'Sales'] = np.nan

# Introduce 3 random NaN values in Quantity
quantity_nan_indices = np.random.choice(df_sales.index, 3, replace=False)
df_sales.loc[quantity_nan_indices, 'Quantity'] = np.nan

print(df_sales)
# Out:
# --- Task 2: Synthetic Data Generation for Practice ---
#                             Date Region  Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South   Laptop  699.0       4.0
# 1  2023-01-01 23:45:27.272727272   East  Monitor  988.0       5.0
# 2  2023-01-02 23:30:54.545454545  South  Monitor  434.0       7.0
# 3  2023-01-03 23:16:21.818181818   East    Mouse  769.0      10.0
# 4  2023-01-04 23:01:49.090909090  South    Mouse  433.0       9.0
# ..                           ...    ...      ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   East    Mouse  275.0       7.0
# 96 2023-04-06 00:43:38.181818182  South    Mouse  729.0       7.0
# 97 2023-04-07 00:29:05.454545455   East  Monitor  260.0       3.0
# 98 2023-04-08 00:14:32.727272728  South    Mouse  426.0       2.0
# 99 2023-04-09 00:00:00.000000000  South   Laptop  689.0       7.0
#
# [100 rows x 5 columns]

# %%
# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

# Your code for Task 3 here:

# %%
# Task 3: Indexing and Slicing in DataFrames

# 3.1 Select only the 'Region' and 'Sales' columns
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where 'Product' is 'Laptop'
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where 'Region' is 'East' AND 'Sales' > 500
df3_3 = df_sales[(df_sales['Region'] == 'East') & (df_sales['Sales'] > 500)]

# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor'
monitor_rows = df_sales[df_sales['Product'] == 'Monitor']

# Using .loc and .iloc
val3_4 = df_sales.loc[monitor_rows.index[0], 'Sales']

print("3.1:")
print(df3_1)

print("\n3.2:")
print(df3_2)

print("\n3.3:")
print(df3_3)

print("\n3.4 Sales value of first Monitor:")
print(val3_4)
# Out:
# 3.1:
#    Region  Sales
# 0   South  699.0
# 1    East  988.0
# 2   South  434.0
# 3    East  769.0
# 4   South  433.0
# ..    ...    ...
# 95   East  275.0
# 96  South  729.0
# 97   East  260.0
# 98  South  426.0
# 99  South  689.0
#
# [100 rows x 2 columns]
#
# 3.2:
#                             Date Region Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South  Laptop  699.0       4.0
# 6  2023-01-06 22:32:43.636363636   East  Laptop  891.0       3.0
# 7  2023-01-07 22:18:10.909090909  South  Laptop  695.0       8.0
# 15 2023-01-15 20:21:49.090909091  North  Laptop  897.0       4.0
# 18 2023-01-18 19:38:10.909090909  South  Laptop  537.0       7.0
# 22 2023-01-22 18:40:00.000000000  South  Laptop  989.0       8.0
# 23 2023-01-23 18:25:27.272727273  South  Laptop  597.0       2.0
# 27 2023-01-27 17:27:16.363636364   East  Laptop  845.0       5.0
# 31 2023-01-31 16:29:05.454545455  South  Laptop  676.0       4.0
# 34 2023-02-03 15:45:27.272727273  North  Laptop  225.0       9.0
# 36 2023-02-05 15:16:21.818181818   West  Laptop  800.0       1.0
# 44 2023-02-13 13:20:00.000000000  North  Laptop  762.0       2.0
# 51 2023-02-20 11:38:10.909090909   West  Laptop    NaN       3.0
# 55 2023-02-24 10:40:00.000000000   West  Laptop  705.0      10.0
# 57 2023-02-26 10:10:54.545454546   East  Laptop  659.0       8.0
# 60 2023-03-01 09:27:16.363636364   East  Laptop    NaN       9.0
# 61 2023-03-02 09:12:43.636363637  South  Laptop  396.0       6.0
# 67 2023-03-08 07:45:27.272727273   West  Laptop  956.0       4.0
# 69 2023-03-10 07:16:21.818181819  North  Laptop  687.0       3.0
# 71 2023-03-12 06:47:16.363636364   West  Laptop  485.0       4.0
# 73 2023-03-14 06:18:10.909090910  North  Laptop  840.0      10.0
# 76 2023-03-17 05:34:32.727272728   West  Laptop  635.0       4.0
# 77 2023-03-18 05:20:00.000000001  South  Laptop  587.0       8.0
# 82 2023-03-23 04:07:16.363636364   East  Laptop  819.0       3.0
# 84 2023-03-25 03:38:10.909090910  North  Laptop  229.0       9.0
# 89 2023-03-30 02:25:27.272727273  South  Laptop  157.0       2.0
# 90 2023-03-31 02:10:54.545454546   East  Laptop  207.0       9.0
# 92 2023-04-02 01:41:49.090909092  North  Laptop  789.0       9.0
# 99 2023-04-09 00:00:00.000000000  South  Laptop  689.0       7.0
#
# 3.3:
#                             Date Region   Product  Sales  Quantity
# 1  2023-01-01 23:45:27.272727272   East   Monitor  988.0       5.0
# 3  2023-01-03 23:16:21.818181818   East     Mouse  769.0      10.0
# 6  2023-01-06 22:32:43.636363636   East    Laptop  891.0       3.0
# 8  2023-01-08 22:03:38.181818181   East  Keyboard  581.0       9.0
# 10 2023-01-10 21:34:32.727272727   East  Keyboard  810.0       5.0
# 14 2023-01-14 20:36:21.818181818   East     Mouse  954.0       4.0
# 27 2023-01-27 17:27:16.363636364   East    Laptop  845.0       5.0
# 42 2023-02-11 13:49:05.454545455   East  Keyboard  691.0      10.0
# 45 2023-02-14 13:05:27.272727273   East     Mouse  901.0       8.0
# 50 2023-02-19 11:52:43.636363636   East   Monitor  772.0       2.0
# 57 2023-02-26 10:10:54.545454546   East    Laptop  659.0       8.0
# 66 2023-03-07 08:00:00.000000000   East   Monitor  609.0       3.0
# 82 2023-03-23 04:07:16.363636364   East    Laptop  819.0       3.0
# 93 2023-04-03 01:27:16.363636364   East     Mouse  641.0       9.0
#
# 3.4 Sales value of first Monitor:
# 988.0

# %%
# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

# Your code for Task 4 here:
# Task 4: Data Cleaning (Handling Missing Values)

# 4.1 Check how many missing values are in each column
missing_counts4_1 = df_sales.isnull().sum()

# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column
df4_2_filled = df_sales.copy()
df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(
    df4_2_filled['Sales'].mean()
)

# 4.3 Drop rows that have any missing values
df4_3_dropped = df_sales.dropna()

print("4.1 Missing Values:")
print(missing_counts4_1)

print("\n4.2 DataFrame after filling Sales:")
print(df4_2_filled)

print("\n4.3 DataFrame after dropping missing rows:")
print(df4_3_dropped)
# Out:
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# 4.1 Missing Values:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# 4.2 DataFrame after filling Sales:
#                             Date Region  Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South   Laptop  699.0       4.0
# 1  2023-01-01 23:45:27.272727272   East  Monitor  988.0       5.0
# 2  2023-01-02 23:30:54.545454545  South  Monitor  434.0       7.0
# 3  2023-01-03 23:16:21.818181818   East    Mouse  769.0      10.0
# 4  2023-01-04 23:01:49.090909090  South    Mouse  433.0       9.0
# ..                           ...    ...      ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   East    Mouse  275.0       7.0
# 96 2023-04-06 00:43:38.181818182  South    Mouse  729.0       7.0
# 97 2023-04-07 00:29:05.454545455   East  Monitor  260.0       3.0
# 98 2023-04-08 00:14:32.727272728  South    Mouse  426.0       2.0
# 99 2023-04-09 00:00:00.000000000  South   Laptop  689.0       7.0
#
# [100 rows x 5 columns]
#
# 4.3 DataFrame after dropping missing rows:
#                             Date Region  Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South   Laptop  699.0       4.0
# 1  2023-01-01 23:45:27.272727272   East  Monitor  988.0       5.0
# 2  2023-01-02 23:30:54.545454545  South  Monitor  434.0       7.0
# 3  2023-01-03 23:16:21.818181818   East    Mouse  769.0      10.0
# 4  2023-01-04 23:01:49.090909090  South    Mouse  433.0       9.0
# ..                           ...    ...      ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   East    Mouse  275.0       7.0
# 96 2023-04-06 00:43:38.181818182  South    Mouse  729.0       7.0
# 97 2023-04-07 00:29:05.454545455   East  Monitor  260.0       3.0
# 98 2023-04-08 00:14:32.727272728  South    Mouse  426.0       2.0
# 99 2023-04-09 00:00:00.000000000  South   Laptop  689.0       7.0
#
# [92 rows x 5 columns]

# %%
# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

# Your code for Task 5 here:

# %%
# Task 5: Data Manipulation (Columns, Sorting, Grouping)

# 5.1 Create Total_Revenue column
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by Date ascending, then Sales descending
df5_2_sorted = df_sales.sort_values(
    by=['Date', 'Sales'],
    ascending=[True, False]
)

# 5.3 Group by Region and calculate sum of Sales and Quantity
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4 Group by Product and calculate average Sales
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print("5.1 Total Revenue:")
print(df_sales)

print("\n5.2 Sorted DataFrame:")
print(df5_2_sorted)

print("\n5.3 Sales and Quantity by Region:")
print(df5_3_grouped_region)

print("\n5.4 Average Sales by Product:")
print(df5_4_grouped_product)
# Out:
# 5.1 Total Revenue:
#                             Date Region  Product  Sales  Quantity  \
# 0  2023-01-01 00:00:00.000000000  South   Laptop  699.0       4.0
# 1  2023-01-01 23:45:27.272727272   East  Monitor  988.0       5.0
# 2  2023-01-02 23:30:54.545454545  South  Monitor  434.0       7.0
# 3  2023-01-03 23:16:21.818181818   East    Mouse  769.0      10.0
# 4  2023-01-04 23:01:49.090909090  South    Mouse  433.0       9.0
# ..                           ...    ...      ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   East    Mouse  275.0       7.0
# 96 2023-04-06 00:43:38.181818182  South    Mouse  729.0       7.0
# 97 2023-04-07 00:29:05.454545455   East  Monitor  260.0       3.0
# 98 2023-04-08 00:14:32.727272728  South    Mouse  426.0       2.0
# 99 2023-04-09 00:00:00.000000000  South   Laptop  689.0       7.0
#
#     Total_Revenue
# 0          2796.0
# 1          4940.0
# 2          3038.0
# 3          7690.0
# 4          3897.0
# ..            ...
# 95         1925.0
# 96         5103.0
# 97          780.0
# 98          852.0
# 99         4823.0
#
# [100 rows x 6 columns]
#
# 5.2 Sorted DataFrame:
#                             Date Region  Product  Sales  Quantity  \
# 0  2023-01-01 00:00:00.000000000  South   Laptop  699.0       4.0
# 1  2023-01-01 23:45:27.272727272   East  Monitor  988.0       5.0
# 2  2023-01-02 23:30:54.545454545  South  Monitor  434.0       7.0
# 3  2023-01-03 23:16:21.818181818   East    Mouse  769.0      10.0
# 4  2023-01-04 23:01:49.090909090  South    Mouse  433.0       9.0
# ..                           ...    ...      ...    ...       ...
# 95 2023-04-05 00:58:10.909090910   East    Mouse  275.0       7.0
# 96 2023-04-06 00:43:38.181818182  South    Mouse  729.0       7.0
# 97 2023-04-07 00:29:05.454545455   East  Monitor  260.0       3.0
# 98 2023-04-08 00:14:32.727272728  South    Mouse  426.0       2.0
# 99 2023-04-09 00:00:00.000000000  South   Laptop  689.0       7.0
#
#     Total_Revenue
# 0          2796.0
# 1          4940.0
# 2          3038.0
# 3          7690.0
# 4          3897.0
# ..            ...
# 95         1925.0
# 96         5103.0
# 97          780.0
# 98          852.0
# 99         4823.0
#
# [100 rows x 6 columns]
#
# 5.3 Sales and Quantity by Region:
#           Sales  Quantity
# Region
# East    12783.0     141.0
# North   13156.0     141.0
# South   14773.0     135.0
# West    16158.0     137.0
#
# 5.4 Average Sales by Product:
# Product
# Keyboard    523.000000
# Laptop      646.407407
# Monitor     595.733333
# Mouse       618.241379
# Name: Sales, dtype: float64
